# %% [markdown]
# # EDA: CPU Benchmarks

# %%
# In this dataset, we will be taking a comprehensive look at CPU dataset which showes the performance of CPU's, their manufacttures etc.
# We will be using the following libraries:
import pandas as pd # this package processes the data, in this case a csv 
import numpy as np # this package is used for scientific computing (linear algebra)
import matplotlib.pyplot as plt # this package is used for plotting and visualizing data
import seaborn as sns # this package is used for plotting and visualizing data

# %%
# Here we are simply reading the csv file and storing it in a variable called df1 standing for data frame 1
#This dataset contains 209 rows and 36 columns, listing 209 CPUs and their characteristics
df1 = pd.read_csv('/Users/danielharrod/git/cpu_project/CPU_benchmark_v4.csv') 
df1
# Out:
#                                 cpuName    price  cpuMark  cpuValue  \
# 0     AMD Ryzen Threadripper PRO 5995WX      NaN   108822       NaN
# 1                         AMD EPYC 7763  7299.99    88338     12.10
# 2                         AMD EPYC 7J13      NaN    86006       NaN
# 3                         AMD EPYC 7713  7060.00    85861     12.16
# 4     AMD Ryzen Threadripper PRO 3995WX  6807.98    83971     12.33
# ...                                 ...      ...      ...       ...
# 3820            Intel Pentium 4 1.60GHz      NaN       84       NaN
# 3821            Intel Pentium 4 1400MHz      NaN       83       NaN
# 3822            Intel Pentium 4 1500MHz      NaN       81       NaN
# 3823                   VIA Eden 1000MHz      NaN       80       NaN
# 3824            Intel Pentium 4 1300MHz      NaN       77       NaN
#
#       threadMark  threadValue    TDP powerPerf  cores  testDate    socket  \
# 0           3330          NaN  280.0    388.65     64      2022     sWRX8
# ...

# %%
df1.describe() # this function gives us a statistical summary of the data
# Out:
#              price        cpuMark     cpuValue   threadMark  threadValue  \
# count  1967.000000    3825.000000  1967.000000  3825.000000  1967.000000
# mean    441.500946    5992.305882    35.354911  1391.107451    15.189009
# std     907.429724    9617.551479    35.812030   815.667528    17.907163
# min       3.990000      77.000000     0.220000    75.000000     0.130000
# 25%      65.000000     943.000000    12.490000   729.000000     4.540000
# 50%     161.000000    2331.000000    25.630000  1274.000000     9.760000
# 75%     393.015000    6643.000000    45.770000  1961.000000    19.025000
# max    8978.000000  108822.000000   345.330000  4317.000000   267.820000
#
#                TDP        cores     testDate
# count  3140.000000  3825.000000  3825.000000
# mean     62.375557     5.052288  2015.027974
# std      47.555107     6.185833     4.597616
# min       2.000000     1.000000  2007.000000
# 25%      28.000000     2.000000  2011.000000
# ...

# %%
df1.info() # this function gives us information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3825 entries, 0 to 3824
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cpuName      3825 non-null   object
#  1   price        1967 non-null   float64
#  2   cpuMark      3825 non-null   int64
#  3   cpuValue     1967 non-null   float64
#  4   threadMark   3825 non-null   int64
#  5   threadValue  1967 non-null   float64
#  6   TDP          3140 non-null   float64
#  7   powerPerf    3140 non-null   object
#  8   cores        3825 non-null   int64
#  9   testDate     3825 non-null   int64
#  10  socket       3825 non-null   object
#  11  category     3825 non-null   object
# dtypes: float64(4), int64(4), object(4)
# memory usage: 358.7+ KB

# %%
sns.pairplot(df1) # this function plots the data in a pairplot

# %%
# Here we are simply reading the csv file and storing it in a variable called df2 standing for data frame 2
df2 = pd.read_csv('/Users/danielharrod/git/cpu_project/CPU_r23_v2.csv')
df2
# Out:
#     manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0            AMD       Threadripper 3990X         1262       75671     64
# 1            AMD  Threadripper Pro 3995WX         1231       73220     64
# 2            AMD               Epyc 7702P          993       48959     64
# 3            AMD       Threadripper 3970X         1308       46874     32
# 4            AMD  Threadripper Pro 3975WX         1244       43450     32
# ..           ...                      ...          ...         ...    ...
# 210          AMD           Ryzen 3 4300GE         1215        5798      4
# 211        Intel           Core i7 1185G7         1473        5783      4
# 212        Intel           Core i7 11370H         1535        5778      4
# 213        Intel           Core i3 10105F         1172        5776      4
# 214          AMD             Ryzen 3 3100         1105        5423      4
#
#      threads  baseClock  turboClock     type
# ...

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of     manufacturer                  cpuName  singleScore  multiScore  cores  \
# 0            AMD       Threadripper 3990X         1262       75671     64
# 1            AMD  Threadripper Pro 3995WX         1231       73220     64
# 2            AMD               Epyc 7702P          993       48959     64
# 3            AMD       Threadripper 3970X         1308       46874     32
# 4            AMD  Threadripper Pro 3975WX         1244       43450     32
# ..           ...                      ...          ...         ...    ...
# 210          AMD           Ryzen 3 4300GE         1215        5798      4
# 211        Intel           Core i7 1185G7         1473        5783      4
# 212        Intel           Core i7 11370H         1535        5778      4
# 213        Intel           Core i3 10105F         1172        5776      4
# 214          AMD             Ryzen 3 3100         1105        5423      4
#
#      threads  baseClock  turboClock     type
# ...

# %%
sns.pairplot(df2) # this function plots the data of our second data set in a pairplot

# %%
# this function counts the number of each type of CPU in the dataset
cputype = (df2['type'].value_counts(sort=False))
cputype
# Out:
# Desktop    144
# Laptop      71
# Name: type, dtype: int64

# %%
cputype_names = (df2['type'].unique())
cputype_names
# Out:
# array(['Desktop', 'Laptop'], dtype=object)

# %% [markdown]
# # Market Share of CPU types

# %%
fig = plt.figure(figsize=(10,10)) 
plt.pie(cputype, labels=cputype_names, autopct='%1.1f%%')
plt.title('CPU Type Market Share ')
plt.show()

# %%
df2_core_scores = df2.drop(columns=['manufacturer', 'cpuName', 'singleScore', 'threads', 
                                    'baseClock', 'turboClock', 'type'])
df2_core_scores.sort_values('cores')
# Out:
#      multiScore  cores
# 214        5423      4
# 158        8467      4
# 156        8504      4
# 213        5776      4
# 190        6845      4
# ..          ...    ...
# 4         43450     32
# 3         46874     32
# 2         48959     64
# 1         73220     64
# 0         75671     64
#
# [215 rows x 2 columns]

# %% [markdown]
# ## Number of Cores vs Mutli-core Score

# %%
df2_core_scores.plot(x='cores', y='multiScore', kind='scatter')
plt.title('Cores vs Multi Score')
plt.show()

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import preprocessing, svm 
sklearn.linear_model.LinearRegression
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
df2_cores_turbo = df2.drop(columns=['manufacturer', 'cpuName', 'multiScore', 'threads', 'baseClock', 'cores', 'type'])
df2_cores_turbo.sort_values('singleScore')
# Out:
#      singleScore  turboClock
# 198          903         3.6
# 194          949         4.0
# 164          954         3.7
# 189          966         3.6
# 136          983         4.0
# ..           ...         ...
# 15          1950         5.0
# 16          1958         5.0
# 9           1974         5.2
# 8           2007         5.2
# 10          2082         5.5
#
# [215 rows x 2 columns]

# %% [markdown]
# ## Turbo Clock Rate vs Single-core Score

# %%
df2_cores_turbo.plot(x='turboClock', y='singleScore', kind='scatter')
plt.title('Turbo Clock vs Single Score')
plt.show()

# %% [markdown]
# ## Benchmark conclusion
# #####  There is a postive correlation between number of cores and the multi-core score printed above. There is also a postive correlation between the turboclock rate and single-core score.

# %% [markdown]
# ## Number of CPU for Socket Type

# %%
fig = plt.figure(figsize=(100,10))
df1['socket'].value_counts().plot.bar(color=['red', 'blue', 'green', 'yellow', 'orange', 'purple'])
plt.title('Number of CPUs per Socket type')
plt.show()

# %%
# Too many socket types to see, so we will only view the top ones 
top30sockets = df1.socket.value_counts()

# %%
top30sockets
# Out:
# unknown      788
# AM4          133
# LGA1155      103
# FCLGA1200     97
# LGA775        89
#             ...
# AM2,AM2+       1
# FCBGA2227      1
# FS1 uPGA       1
# LGA2011-1      1
# FT5            1
# Name: socket, Length: 203, dtype: int64

# %%
top30sockets_test = df1['socket'].value_counts()

# %%
topSockets = df1[~df1['socket'].isin(top30sockets_test[top30sockets_test < 10].index)]
topSockets
# Out:
#                               cpuName    price  cpuMark  cpuValue  threadMark  \
# 1                       AMD EPYC 7763  7299.99    88338     12.10        2635
# 2                       AMD EPYC 7J13      NaN    86006       NaN        2387
# 3                       AMD EPYC 7713  7060.00    85861     12.16        2727
# 7                       AMD EPYC 7B13      NaN    77460       NaN        2564
# 8                       AMD EPYC 7643  5424.99    76455     14.09        2695
# ...                               ...      ...      ...       ...         ...
# 3813  Intel Pentium III Mobile 866MHz      NaN       99       NaN         132
# 3814            Intel Celeron 1.80GHz      NaN       96       NaN         307
# 3815               VIA Esther 1000MHz      NaN       95       NaN          82
# 3817     ARM Cortex-A7 2 Core 960 MHz      NaN       93       NaN         140
# 3820          Intel Pentium 4 1.60GHz      NaN       84       NaN         225
#
# ...

# %%
fig = plt.figure(figsize=(20,10))
topSockets['socket'].value_counts().plot.bar(color=['red', 'blue', 'green', 'yellow', 'orange'])
plt.title('Number of CPUs per Socket type')
plt.show()

# %% [markdown]
# #### We will now remove the unknowns from the figure above

# %%
topSockets_clean = topSockets[topSockets.socket != 'unknown']
topSockets_clean
# Out:
#                            cpuName    price  cpuMark  cpuValue  threadMark  \
# 1                    AMD EPYC 7763  7299.99    88338     12.10        2635
# 3                    AMD EPYC 7713  7060.00    85861     12.16        2727
# 8                    AMD EPYC 7643  5424.99    76455     14.09        2695
# 9                    AMD EPYC 7702  4000.00    71646     17.91        2097
# 10                   AMD EPYC 7662  6817.00    71576     10.50        2054
# ...                            ...      ...      ...       ...         ...
# 3803       Intel Pentium 4 1.80GHz      NaN      115       NaN         318
# 3804       Intel Pentium 4 1800MHz      NaN      114       NaN         317
# 3808  Intel Celeron B710 @ 1.60GHz      NaN      106       NaN         101
# 3814         Intel Celeron 1.80GHz      NaN       96       NaN         307
# 3820       Intel Pentium 4 1.60GHz      NaN       84       NaN         225
#
# ...

# %%
fig = plt.figure(figsize=(20,10))
topSockets_clean['socket'].value_counts().plot.bar(color=['red', 'blue', 'green', 'yellow', 'orange'])
plt.title('Number of CPUs per Socket type, cleaned')
plt.show()

# %% [markdown]
# ## Socket Types
# #### Using the figure above we can see that AM4 seems to be the most popular socket type used.
